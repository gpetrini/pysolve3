# %% [markdown]
# **Test:** Including numpy functions in package

# %%
from pysolve3.model import Model
from pysolve3.utils import SolveSFC, ShockModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def teste():
    from sympy import lambdify
    import sympy as sp
    x = sp.Symbol('x')
    mod = Model()
    mod.set_var_default(0)
    
    mod.var('y', default = 0.0005)
    mod.var('gz')
    
    mod.add('y = (sin(y(-1)*100))')
    mod.add('gz = y/100')
    return mod
SolveSFC(teste())['gz'][:100].plot()
